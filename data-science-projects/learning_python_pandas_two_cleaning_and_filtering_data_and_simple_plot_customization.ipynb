# %% [markdown]
# # Cleaning and Filtering data in a DataFrame

# %% [markdown]
# Objective:
#
#     1. Extract subsets of data from our DataFrame
#     2. Perfrom data query and filtering
#     3. Perfrom data cleanup

# %% [markdown]
# # First, let's import pandas and read our data

# %%
# import pandas and give it an alias
import pandas as pd

# %%
# read intel-stock-data.csv file
psei_df = pd.read_csv('data/psei-data.csv')

# let's see what it contains
psei_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2022-03-07  7304.759766  7304.759766  7158.330078  7288.069824
# 1    2022-03-08  7167.950195  7176.189941  6977.729980  6977.729980
# 2    2022-03-09  6967.540039  7095.120117  6967.540039  6989.879883
# 3    2022-03-10  7094.779785  7125.399902  7043.450195  7124.799805
# 4    2022-03-11  7084.779785  7112.189941  7044.839844  7112.189941
# ..          ...          ...          ...          ...          ...
# 256  2023-02-28  6609.410156  6670.490234  6556.200195  6556.200195
# 257  2023-03-01  6602.959961  6630.200195  6579.479980  6607.129883
# 258  2023-03-02  6628.350098  6690.629883  6598.149902  6622.450195
# 259  2023-03-03  6640.330078  6694.359863  6640.330078  6655.370117
# 260  2023-03-06     0.000000     0.000000     0.000000  6671.120117
#
#        Adj Close    Volume
# 0    7288.069824  158600.0
# 1    6977.729980  231700.0
# 2    6989.879883  156500.0
# 3    7124.799805  129800.0
# ...

# %% [markdown]
# # Filtering Data in a DataFrame

# %% [markdown]
# Refference:
#
# https://builtin.com/data-science/pandas-filter
#
# https://www.listendata.com/2019/07/how-to-filter-pandas-dataframe.html
#
# https://blog.hubspot.com/website/filter-rows-pandas

# %% [markdown]
# Extracting Subsets of Data

# %%
year_2022_df = psei_df.loc[(psei_df['Date']>='2023-01-01') & (psei_df['Date']<='2023-03-31'), ['Date', 'Open', 'Close']]
year_2022_df
# Out:
#            Date         Open        Close
# 215  2023-01-02          NaN          NaN
# 216  2023-01-03  6555.399902  6586.009766
# 217  2023-01-04  6601.500000  6718.500000
# 218  2023-01-05  6738.930176  6761.330078
# 219  2023-01-06  6736.649902  6667.970215
# 220  2023-01-09  6692.299805  6790.240234
# 221  2023-01-10  6783.399902  6756.689941
# 222  2023-01-11  6764.680176  6709.339844
# 223  2023-01-12  6723.529785  6833.529785
# 224  2023-01-13  6833.759766  6951.540039
# 225  2023-01-16  6966.000000  7045.479980
# 226  2023-01-17  7041.060059  7014.040039
# 227  2023-01-18  7008.069824  7094.859863
# 228  2023-01-19  7049.799805  7062.009766
# 229  2023-01-20  7056.430176  7056.620117
# 230  2023-01-23  7051.459961  7069.680176
# 231  2023-01-24  7065.600098  7041.500000
# 232  2023-01-25  7072.490234  7081.359863
# 233  2023-01-26  7088.140137  7042.700195
# 234  2023-01-27  7062.629883  7052.160156
# 235  2023-01-30  7048.759766  6970.970215
# ...

# %%
year_2022_df.describe()
# Out:
#               Open        Close
# count    45.000000    45.000000
# mean   6696.365994  6844.097114
# std    1032.731262   161.368663
# min       0.000000  6556.200195
# 25%    6723.529785  6709.339844
# 50%    6814.520020  6822.089844
# 75%    7008.069824  7014.040039
# max    7088.140137  7094.859863

# %%
year_2022_df.plot.line(x='Date')
# Out:
# <Axes: xlabel='Date'>

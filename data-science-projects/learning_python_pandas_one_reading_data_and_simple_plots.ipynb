# %% [markdown]
# # Learning Python Pandas
# Objective:
#     1. importing libraries
#     2. open csv file using pandas
#         2.1. creating and using DataFrame
#     3. exploring some DataFrame functions and attributes
#         3.1 Head and Tail to display top and bottom number of rows

# %%
# import pandas and give it an alias (pd)
import pandas as pd

# next, let's import pyplot from matplotlib
# give it an alias of plt
from matplotlib import pyplot as plt

# %%
# read intel-stock-data.csv file
# read_csv will return a DataFrame object
intel_stock_df = pd.read_csv('data/psei-data.csv')

# let's validate the type of intel_stock_df
type(intel_stock_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# a DataFrame is a row and column of data
intel_stock_df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2022-03-07  7304.759766  7304.759766  7158.330078  7288.069824
# 1    2022-03-08  7167.950195  7176.189941  6977.729980  6977.729980
# 2    2022-03-09  6967.540039  7095.120117  6967.540039  6989.879883
# 3    2022-03-10  7094.779785  7125.399902  7043.450195  7124.799805
# 4    2022-03-11  7084.779785  7112.189941  7044.839844  7112.189941
# ..          ...          ...          ...          ...          ...
# 256  2023-02-28  6609.410156  6670.490234  6556.200195  6556.200195
# 257  2023-03-01  6602.959961  6630.200195  6579.479980  6607.129883
# 258  2023-03-02  6628.350098  6690.629883  6598.149902  6622.450195
# 259  2023-03-03  6640.330078  6694.359863  6640.330078  6655.370117
# 260  2023-03-06     0.000000     0.000000     0.000000  6671.120117
#
#        Adj Close    Volume
# 0    7288.069824  158600.0
# 1    6977.729980  231700.0
# 2    6989.879883  156500.0
# 3    7124.799805  129800.0
# ...

# %%
# let's take a look at the shape 
# of our DataFrame
# shape is a property shows the 
# number of rows and columns (r, c)
# in the dataframe
intel_stock_df.shape
# Out:
# (261, 7)

# %%
# the columns attribute and array
# of column names with in the dataframe
type(intel_stock_df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
# let's get some information 
# about our DataFrame
intel_stock_df.info()

# the first line tells us that it's a DataFrame
# There are 254 rows. Range Index is 0 to 253
# it shows the columns, non-null count 
# and the datatype of each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       261 non-null    object
#  1   Open       248 non-null    float64
#  2   High       248 non-null    float64
#  3   Low        248 non-null    float64
#  4   Close      248 non-null    float64
#  5   Adj Close  248 non-null    float64
#  6   Volume     248 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 14.4+ KB

# %%
# the describe function gives you 
# some statistical information about
# about the DataFrame.
intel_stock_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   248.000000   248.000000   248.000000   248.000000   248.000000
# mean   6569.651728  6608.172334  6517.996421  6593.609343  6593.609343
# std     535.717139   536.982685   532.866994   336.954374   336.954374
# min       0.000000     0.000000     0.000000  5741.069824  5741.069824
# 25%    6346.217407  6373.867675  6299.859985  6348.807495  6348.807495
# 50%    6613.795166  6676.034912  6572.800049  6607.034912  6607.034912
# 75%    6832.500000  6871.315064  6777.357666  6822.897339  6822.897339
# max    7304.759766  7304.759766  7158.330078  7288.069824  7288.069824
#
#              Volume
# count  2.480000e+02
# mean   1.471621e+05
# std    1.256710e+05
# min    0.000000e+00
# 25%    9.635000e+04
# 50%    1.228000e+05
# 75%    1.586000e+05
# max    1.304800e+06

# %%
# you can also take a look at the first nRows
# with in the DataFrame by using the head(n) function
# here we're loading the first 10 rows from the DataFrame
intel_stock_df.head(10)
# Out:
#          Date         Open         High          Low        Close  \
# 0  2022-03-07  7304.759766  7304.759766  7158.330078  7288.069824
# 1  2022-03-08  7167.950195  7176.189941  6977.729980  6977.729980
# 2  2022-03-09  6967.540039  7095.120117  6967.540039  6989.879883
# 3  2022-03-10  7094.779785  7125.399902  7043.450195  7124.799805
# 4  2022-03-11  7084.779785  7112.189941  7044.839844  7112.189941
# 5  2022-03-14  7076.790039  7076.790039  6797.089844  6816.950195
# 6  2022-03-15  6820.779785  7019.919922  6638.399902  7019.919922
# 7  2022-03-16  7004.569824  7026.450195  6957.459961  7026.450195
# 8  2022-03-17  7053.540039  7156.770020  7046.560059  7122.450195
# 9  2022-03-18  7112.000000  7140.899902  7007.629883  7007.629883
#
#      Adj Close    Volume
# 0  7288.069824  158600.0
# 1  6977.729980  231700.0
# 2  6989.879883  156500.0
# 3  7124.799805  129800.0
# 4  7112.189941  118900.0
# 5  6816.950195  171900.0
# 6  7019.919922  172500.0
# 7  7026.450195  143200.0
# ...

# %%
# you can also take a look at the bottom nRows
# in the DataFrame. You can do this using the tail(n)
# function
intel_stock_df.tail(10)
# Out:
#            Date         Open         High          Low        Close  \
# 251  2023-02-21  6757.950195  6800.959961  6719.100098  6800.959961
# 252  2023-02-22  6778.200195  6778.200195  6696.720215  6699.229980
# 253  2023-02-23  6704.910156  6704.910156  6666.410156  6685.899902
# 254  2023-02-24  6704.910156  6704.910156  6666.410156  6685.899902
# 255  2023-02-27  6684.450195  6684.450195  6537.520020  6599.339844
# 256  2023-02-28  6609.410156  6670.490234  6556.200195  6556.200195
# 257  2023-03-01  6602.959961  6630.200195  6579.479980  6607.129883
# 258  2023-03-02  6628.350098  6690.629883  6598.149902  6622.450195
# 259  2023-03-03  6640.330078  6694.359863  6640.330078  6655.370117
# 260  2023-03-06     0.000000     0.000000     0.000000  6671.120117
#
#        Adj Close    Volume
# 251  6800.959961   82300.0
# 252  6699.229980  115300.0
# 253  6685.899902  129200.0
# 254  6685.899902  129200.0
# 255  6599.339844  165400.0
# 256  6556.200195  767400.0
# ...

# %%
# A Series is a column in the DataFrame
# you can access a series by using DataFrame['column_name']
# example:
intel_stock_df['Open']

# note: column name is case sensitive meaning,
# it has to be thesame with the column name 
# on the CSV file.
# intel_stock_df['open'] will generate an error:
# KeyError: 'open'
# Out:
# 0      7304.759766
# 1      7167.950195
# 2      6967.540039
# 3      7094.779785
# 4      7084.779785
#           ...
# 256    6609.410156
# 257    6602.959961
# 258    6628.350098
# 259    6640.330078
# 260       0.000000
# Name: Open, Length: 261, dtype: float64

# %%
# here's another example where I extract 3 columns
# from the DataFrame and get only the first 20 rows
intel_stock_df[['Date', 'Open', 'High', 'Low']].head(20)
# Out:
#           Date         Open         High          Low
# 0   2022-03-07  7304.759766  7304.759766  7158.330078
# 1   2022-03-08  7167.950195  7176.189941  6977.729980
# 2   2022-03-09  6967.540039  7095.120117  6967.540039
# 3   2022-03-10  7094.779785  7125.399902  7043.450195
# 4   2022-03-11  7084.779785  7112.189941  7044.839844
# 5   2022-03-14  7076.790039  7076.790039  6797.089844
# 6   2022-03-15  6820.779785  7019.919922  6638.399902
# 7   2022-03-16  7004.569824  7026.450195  6957.459961
# 8   2022-03-17  7053.540039  7156.770020  7046.560059
# 9   2022-03-18  7112.000000  7140.899902  7007.629883
# 10  2022-03-21  7024.790039  7054.979980  6949.850098
# 11  2022-03-22  6940.850098  7008.939941  6900.490234
# 12  2022-03-23  6986.189941  7013.669922  6977.609863
# 13  2022-03-24  7013.390137  7082.609863  6985.470215
# 14  2022-03-25  7073.609863  7124.839844  7048.529785
# 15  2022-03-28  7120.740234  7134.359863  7080.370117
# ...

# %% [markdown]
# # Plotting Basics

# %%
# this is the default plot
intel_stock_df.plot()
# Out:
# <Axes: >

# %%
# let's try to plot this intel stock data
# plot line graph from our DataFrame
intel_stock_df.plot.line()
# Out:
# <Axes: >

# %%
# setting subplots=True will plot
# each axis individually
intel_stock_df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
# each chart or graph has its own default colors
# that can be overriden by specifying color values (dict)


# remove the subplots=True and 
# you will get one graph with different
# colors from the default

# let's continue where we left
axis = intel_stock_df.plot.line(
    subplots=True,
    x='Date',
    color={
        'Open': '#a4cb47',
        'High': '#f3bb69',
        'Low': '#599849',
        'Close': '#aed0a7',
        'Adj Close': '#000000',
        'Volume': '#ff3344'
    }
)

# %%
# here's a line chart with close values by date
intel_stock_df.plot(
    kind='line', x='Date', y=['Open', 'Close'],
    color={
        'Open': '#a4cb47',
        'Close': '#599849'
      }
)
# Out:
# <Axes: xlabel='Date'>

# %%
# Next assignment: CandleStick Chart

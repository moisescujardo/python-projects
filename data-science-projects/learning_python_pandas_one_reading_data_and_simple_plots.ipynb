# %% [markdown]
# # Learning Python Pandas
# Objective:
#     1. importing libraries
#     2. open csv file using pandas
#         2.1. creating and using DataFrame
#     3. exploring some DataFrame functions and attributes
#         3.1 Head and Tail to display top and bottom number of rows

# %% [markdown]
# # Import pandas module and read csv file

# %%
# import pandas and give it an alias (pd)
import pandas as pd

# %%
# read psei-data.csv file
# read_csv will return a DataFrame object
psei_df = pd.read_csv('data/psei-data.csv', index_col='Date')

psei_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-03-07  7304.759766  7304.759766  7158.330078  7288.069824  7288.069824
# 2022-03-08  7167.950195  7176.189941  6977.729980  6977.729980  6977.729980
# 2022-03-09  6967.540039  7095.120117  6967.540039  6989.879883  6989.879883
# 2022-03-10  7094.779785  7125.399902  7043.450195  7124.799805  7124.799805
# 2022-03-11  7084.779785  7112.189941  7044.839844  7112.189941  7112.189941
# ...                 ...          ...          ...          ...          ...
# 2023-02-28  6609.410156  6670.490234  6556.200195  6556.200195  6556.200195
# 2023-03-01  6602.959961  6630.200195  6579.479980  6607.129883  6607.129883
# 2023-03-02  6628.350098  6690.629883  6598.149902  6622.450195  6622.450195
# 2023-03-03  6640.330078  6694.359863  6640.330078  6655.370117  6655.370117
# 2023-03-06     0.000000     0.000000     0.000000  6671.120117  6671.120117
#
#               Volume
# Date
# 2022-03-07  158600.0
# 2022-03-08  231700.0
# 2022-03-09  156500.0
# 2022-03-10  129800.0
# 2022-03-11  118900.0
# ...              ...
# 2023-02-28  767400.0
# 2023-03-01  159000.0
# 2023-03-02  149700.0
# 2023-03-03  204300.0
# 2023-03-06       0.0
#
# [261 rows x 6 columns]

# %%
# a DataFrame is a row and column of data
psei_df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-03-07  7304.759766  7304.759766  7158.330078  7288.069824  7288.069824
# 2022-03-08  7167.950195  7176.189941  6977.729980  6977.729980  6977.729980
# 2022-03-09  6967.540039  7095.120117  6967.540039  6989.879883  6989.879883
# 2022-03-10  7094.779785  7125.399902  7043.450195  7124.799805  7124.799805
# 2022-03-11  7084.779785  7112.189941  7044.839844  7112.189941  7112.189941
# ...                 ...          ...          ...          ...          ...
# 2023-02-28  6609.410156  6670.490234  6556.200195  6556.200195  6556.200195
# 2023-03-01  6602.959961  6630.200195  6579.479980  6607.129883  6607.129883
# 2023-03-02  6628.350098  6690.629883  6598.149902  6622.450195  6622.450195
# 2023-03-03  6640.330078  6694.359863  6640.330078  6655.370117  6655.370117
# 2023-03-06     0.000000     0.000000     0.000000  6671.120117  6671.120117
#
#               Volume
# Date
# 2022-03-07  158600.0
# 2022-03-08  231700.0
# 2022-03-09  156500.0
# 2022-03-10  129800.0
# 2022-03-11  118900.0
# ...              ...
# 2023-02-28  767400.0
# 2023-03-01  159000.0
# 2023-03-02  149700.0
# 2023-03-03  204300.0
# 2023-03-06       0.0
#
# [261 rows x 6 columns]

# %% [markdown]
# # Exploring DataFrame Attributes

# %%
# shape is an attribute that shows 
# the number of rows and columns (r, c)
# in the dataframe
psei_df.shape
# Out:
# (261, 7)

# %%
# column returns the column labels
# on this dataframe
psei_df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
# index displays the row 
# labels in a DataFrame
psei_df.index
# Out:
# Index(['2022-03-07', '2022-03-08', '2022-03-09', '2022-03-10', '2022-03-11',
#        '2022-03-14', '2022-03-15', '2022-03-16', '2022-03-17', '2022-03-18',
#        ...
#        '2023-02-21', '2023-02-22', '2023-02-23', '2023-02-24', '2023-02-27',
#        '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03', '2023-03-06'],
#       dtype='object', name='Date', length=261)

# %%
# axes will show you both 
# row and column indexes
psei_df.axes
# Out:
# [RangeIndex(start=0, stop=261, step=1),
#  Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')]

# %%
# dtypes returns the data type
# of each column on the DataFrame.
psei_df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
# size displays the total
# number of elements in
# a DataFrame
psei_df.size
# Out:
# 1827

# %%
# empty returns true if
# if the dataframe is empty
# and false if otherwise
psei_df.empty
# Out:
# False

# %%
# T attribute stands for transpose
# use this if you want to change 
# the columnsto rows and rows 
# to columns

# for example
psei_df.T
# Out:
# Date          2022-03-07     2022-03-08     2022-03-09     2022-03-10  \
# Open         7304.759766    7167.950195    6967.540039    7094.779785
# High         7304.759766    7176.189941    7095.120117    7125.399902
# Low          7158.330078    6977.729980    6967.540039    7043.450195
# Close        7288.069824    6977.729980    6989.879883    7124.799805
# Adj Close    7288.069824    6977.729980    6989.879883    7124.799805
# Volume     158600.000000  231700.000000  156500.000000  129800.000000
#
# Date          2022-03-11     2022-03-14     2022-03-15     2022-03-16  \
# Open         7084.779785    7076.790039    6820.779785    7004.569824
# High         7112.189941    7076.790039    7019.919922    7026.450195
# Low          7044.839844    6797.089844    6638.399902    6957.459961
# Close        7112.189941    6816.950195    7019.919922    7026.450195
# Adj Close    7112.189941    6816.950195    7019.919922    7026.450195
# Volume     118900.000000  171900.000000  172500.000000  143200.000000
#
# Date          2022-03-17     2022-03-18  ...    2023-02-21     2023-02-22  \
# Open         7053.540039    7112.000000  ...   6757.950195    6778.200195
# High         7156.770020    7140.899902  ...   6800.959961    6778.200195
# Low          7046.560059    7007.629883  ...   6719.100098    6696.720215
# Close        7122.450195    7007.629883  ...   6800.959961    6699.229980
# Adj Close    7122.450195    7007.629883  ...   6800.959961    6699.229980
# Volume     157900.000000  367900.000000  ...  82300.000000  115300.000000
#
# Date          2023-02-23     2023-02-24     2023-02-27     2023-02-28  \
# Open         6704.910156    6704.910156    6684.450195    6609.410156
# High         6704.910156    6704.910156    6684.450195    6670.490234
# Low          6666.410156    6666.410156    6537.520020    6556.200195
# Close        6685.899902    6685.899902    6599.339844    6556.200195
# Adj Close    6685.899902    6685.899902    6599.339844    6556.200195
# Volume     129200.000000  129200.000000  165400.000000  767400.000000
#
# Date          2023-03-01     2023-03-02     2023-03-03   2023-03-06
# Open         6602.959961    6628.350098    6640.330078     0.000000
# High         6630.200195    6690.629883    6694.359863     0.000000
# Low          6579.479980    6598.149902    6640.330078     0.000000
# Close        6607.129883    6622.450195    6655.370117  6671.120117
# Adj Close    6607.129883    6622.450195    6655.370117  6671.120117
# Volume     159000.000000  149700.000000  204300.000000     0.000000
#
# [6 rows x 261 columns]

# %%
# this will display the Date as columns
# and the Open, High, Low, Close, Adj Close,
# Volume as rows
psei_df_t
# Out:
#                    0            1            2            3            4    \
# Date        2022-03-07   2022-03-08   2022-03-09   2022-03-10   2022-03-11
# Open       7304.759766  7167.950195  6967.540039  7094.779785  7084.779785
# High       7304.759766  7176.189941  7095.120117  7125.399902  7112.189941
# Low        7158.330078   6977.72998  6967.540039  7043.450195  7044.839844
# Close      7288.069824   6977.72998  6989.879883  7124.799805  7112.189941
# Adj Close  7288.069824   6977.72998  6989.879883  7124.799805  7112.189941
# Volume        158600.0     231700.0     156500.0     129800.0     118900.0
#
#                    5            6            7            8            9    \
# Date        2022-03-14   2022-03-15   2022-03-16   2022-03-17   2022-03-18
# Open       7076.790039  6820.779785  7004.569824  7053.540039       7112.0
# High       7076.790039  7019.919922  7026.450195   7156.77002  7140.899902
# Low        6797.089844  6638.399902  6957.459961  7046.560059  7007.629883
# Close      6816.950195  7019.919922  7026.450195  7122.450195  7007.629883
# Adj Close  6816.950195  7019.919922  7026.450195  7122.450195  7007.629883
# Volume        171900.0     172500.0     143200.0     157900.0     367900.0
#
#            ...          251          252          253          254  \
# Date       ...   2023-02-21   2023-02-22   2023-02-23   2023-02-24
# Open       ...  6757.950195  6778.200195  6704.910156  6704.910156
# High       ...  6800.959961  6778.200195  6704.910156  6704.910156
# Low        ...  6719.100098  6696.720215  6666.410156  6666.410156
# Close      ...  6800.959961   6699.22998  6685.899902  6685.899902
# Adj Close  ...  6800.959961   6699.22998  6685.899902  6685.899902
# Volume     ...      82300.0     115300.0     129200.0     129200.0
#
#                    255          256          257          258          259  \
# Date        2023-02-27   2023-02-28   2023-03-01   2023-03-02   2023-03-03
# Open       6684.450195  6609.410156  6602.959961  6628.350098  6640.330078
# High       6684.450195  6670.490234  6630.200195  6690.629883  6694.359863
# Low         6537.52002  6556.200195   6579.47998  6598.149902  6640.330078
# Close      6599.339844  6556.200195  6607.129883  6622.450195  6655.370117
# Adj Close  6599.339844  6556.200195  6607.129883  6622.450195  6655.370117
# Volume        165400.0     767400.0     159000.0     149700.0     204300.0
#
#                    260
# Date        2023-03-06
# Open               0.0
# High               0.0
# Low                0.0
# Close      6671.120117
# Adj Close  6671.120117
# Volume             0.0
#
# [7 rows x 261 columns]

# %% [markdown]
# # Exploring DataFrame Functions

# %%
# let's get some information 
# about our DataFrame
psei_df.info()

# the first line tells us that it's a DataFrame
# There are 254 rows. Range Index is 0 to 253
# it shows the columns, non-null count 
# and the datatype of each columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 2022-03-07 to 2023-03-06
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       248 non-null    float64
#  1   High       248 non-null    float64
#  2   Low        248 non-null    float64
#  3   Close      248 non-null    float64
#  4   Adj Close  248 non-null    float64
#  5   Volume     248 non-null    float64
# dtypes: float64(6)
# memory usage: 22.4+ KB

# %%
# the describe function gives you 
# some statistical information about
# about the DataFrame.
psei_df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   248.000000   248.000000   248.000000   248.000000   248.000000
# mean   6569.651728  6608.172334  6517.996421  6593.609343  6593.609343
# std     535.717139   536.982685   532.866994   336.954374   336.954374
# min       0.000000     0.000000     0.000000  5741.069824  5741.069824
# 25%    6346.217407  6373.867675  6299.859985  6348.807495  6348.807495
# 50%    6613.795166  6676.034912  6572.800049  6607.034912  6607.034912
# 75%    6832.500000  6871.315064  6777.357666  6822.897339  6822.897339
# max    7304.759766  7304.759766  7158.330078  7288.069824  7288.069824
#
#              Volume
# count  2.480000e+02
# mean   1.471621e+05
# std    1.256710e+05
# min    0.000000e+00
# 25%    9.635000e+04
# 50%    1.228000e+05
# 75%    1.586000e+05
# max    1.304800e+06

# %%
# you can also take a look at the first nRows
# with in the DataFrame by using the head(n) function
# here we're loading the first 10 rows from the DataFrame
psei_df.head(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-03-07  7304.759766  7304.759766  7158.330078  7288.069824  7288.069824
# 2022-03-08  7167.950195  7176.189941  6977.729980  6977.729980  6977.729980
# 2022-03-09  6967.540039  7095.120117  6967.540039  6989.879883  6989.879883
# 2022-03-10  7094.779785  7125.399902  7043.450195  7124.799805  7124.799805
# 2022-03-11  7084.779785  7112.189941  7044.839844  7112.189941  7112.189941
# 2022-03-14  7076.790039  7076.790039  6797.089844  6816.950195  6816.950195
# 2022-03-15  6820.779785  7019.919922  6638.399902  7019.919922  7019.919922
# 2022-03-16  7004.569824  7026.450195  6957.459961  7026.450195  7026.450195
# 2022-03-17  7053.540039  7156.770020  7046.560059  7122.450195  7122.450195
# 2022-03-18  7112.000000  7140.899902  7007.629883  7007.629883  7007.629883
#
#               Volume
# Date
# 2022-03-07  158600.0
# 2022-03-08  231700.0
# 2022-03-09  156500.0
# 2022-03-10  129800.0
# 2022-03-11  118900.0
# 2022-03-14  171900.0
# 2022-03-15  172500.0
# 2022-03-16  143200.0
# 2022-03-17  157900.0
# 2022-03-18  367900.0

# %%
# you can also take a look at the bottom nRows
# in the DataFrame. You can do this using the tail(n)
# function
psei_df.tail(10)
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-02-21  6757.950195  6800.959961  6719.100098  6800.959961  6800.959961
# 2023-02-22  6778.200195  6778.200195  6696.720215  6699.229980  6699.229980
# 2023-02-23  6704.910156  6704.910156  6666.410156  6685.899902  6685.899902
# 2023-02-24  6704.910156  6704.910156  6666.410156  6685.899902  6685.899902
# 2023-02-27  6684.450195  6684.450195  6537.520020  6599.339844  6599.339844
# 2023-02-28  6609.410156  6670.490234  6556.200195  6556.200195  6556.200195
# 2023-03-01  6602.959961  6630.200195  6579.479980  6607.129883  6607.129883
# 2023-03-02  6628.350098  6690.629883  6598.149902  6622.450195  6622.450195
# 2023-03-03  6640.330078  6694.359863  6640.330078  6655.370117  6655.370117
# 2023-03-06     0.000000     0.000000     0.000000  6671.120117  6671.120117
#
#               Volume
# Date
# 2023-02-21   82300.0
# 2023-02-22  115300.0
# 2023-02-23  129200.0
# 2023-02-24  129200.0
# 2023-02-27  165400.0
# 2023-02-28  767400.0
# 2023-03-01  159000.0
# 2023-03-02  149700.0
# 2023-03-03  204300.0
# 2023-03-06       0.0

# %%
# A Series is a column in the DataFrame
# you can access a series by using DataFrame['column_name']
# example:
psei_df['Open']

# note: column name is case sensitive meaning,
# it has to be thesame with the column name 
# on the CSV file.
# intel_stock_df['open'] will generate an error:
# KeyError: 'open'

# %%
# here's another example where I extract 3 columns
# from the DataFrame and get only the first 20 rows
psei_df[['Open', 'High', 'Low']].head(20)

# %% [markdown]
# # Plotting Basics

# %%
# this is the default plot
psei_df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# let's try to plot this intel stock data
# plot line graph from our DataFrame
psei_df.plot.line()
# Out:
# <Axes: xlabel='Date'>

# %%
# setting subplots=True will plot
# each axis individually
psei_df.plot.line(subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
# each chart or graph has its own default colors
# that can be overriden by specifying color values (dict)


# remove the subplots=True and 
# you will get one graph with different
# colors from the default

# let's continue where we left
axis = psei_df.plot.line(
    subplots=True,
    color={
        'Open': '#a4cb47',
        'High': '#f3bb69',
        'Low': '#599849',
        'Close': '#aed0a7',
        'Adj Close': '#000000',
        'Volume': '#ff3344'
    }
)

# %%
# here's a line chart with close values by date
intel_stock_df.plot(
    kind='line', x='Date', y=['Open', 'Close'],
    color={
        'Open': '#a4cb47',
        'Close': '#599849'
      }
)

# %%
# Next assignment: CandleStick Chart
